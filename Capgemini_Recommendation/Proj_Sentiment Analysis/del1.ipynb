# %%
import tweepy

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Sep  4 15:17:40 2021

@author: nishant_ty
"""

import tweepy


# Fill the X's with the credentials obtained by 
# following the above mentioned procedure.
consumer_key = "utfnX1FrpZvMrxzerP6lSrmDq" 
consumer_secret = "CX3nymeGYWPYkTMbyNFWxyqaLEceBcU2YnoVPbk80Jw3yxfWSB"
access_key = "1489539912-pIkgGYgt4JXnkUZ2pFLXdbxtE7tDPvY86VYIjo5"
access_secret = "6bpFmeOkJ9qs0Xy1T8AfdkBwKGBpfxSilinuHRa5qFzEX"
  
# Function to extract tweets
def get_tweets(username):
          
        # Authorization to consumer key and consumer secret
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  
        # Access to user's access key and access secret
        auth.set_access_token(access_key, access_secret)
  
        # Calling api
        api = tweepy.API(auth)
  
        # 200 tweets to be extracted
        number_of_tweets=2000
        tweets = api.user_timeline(screen_name=username,tweet_mode='extended')
        print (tweets[0])
        # Empty Array
        tmp=[] 
  
        # create array of tweet information: username, 
        # tweet id, date/time, text
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created 
        print (tweet._json["full_text"])
        for j,i in enumerate(tweets_for_csv):
  
            # Appending tweets to the empty array tmp
            tmp.append(i) 
            print (i)
            #break
            tmp.append('***********************************************************')
  
        # Printing the tweets
        #print(tmp)
        with open("outfile.txt", "w") as outfile:
            outfile.write("\n".join(str(item.encode('cp850','replace').decode('cp850')) for item in tmp)) 
 
  
  
# Driver code
if __name__ == '__main__':
  
    # Here goes the twitter handle for the user
    # whose tweets are to be extracted.
    get_tweets("AstellasEurope")
# Out:
# Status(_api=<tweepy.api.API object at 0x000001584E00D4E0>, _json={'created_at': 'Fri Sep 03 10:06:29 +0000 2021', 'id': 1433733127432777746, 'id_str': '1433733127432777746', 'full_text': 'Today is #WorldLeukemiaDay\n\nWe are joining @LeukaemiaCareUK @AcuteLeuk\n@CLLAdvocates @cmlnet to raise awareness of leukemia.\n\nFind out how you can support #WLD21 at: https://t.co/TMa0CBgJFc\n\n#BloodCancerAwarenessMonth  #SpotLeukaemia https://t.co/0Aht5ym32x', 'truncated': False, 'display_text_range': [0, 233], 'entities': {'hashtags': [{'text': 'WorldLeukemiaDay', 'indices': [9, 26]}, {'text': 'WLD21', 'indices': [155, 161]}, {'text': 'BloodCancerAwarenessMonth', 'indices': [191, 217]}, {'text': 'SpotLeukaemia', 'indices': [219, 233]}], 'symbols': [], 'user_mentions': [{'screen_name': 'LeukaemiaCareUK', 'name': 'Leukaemia Care', 'id': 90374395, 'id_str': '90374395', 'indices': [43, 59]}, {'screen_name': 'AcuteLeuk', 'name': 'Acute Leukemia Advocates Network (ALAN)', 'id': 892027226937597953, 
# ...

# %%
import tweepy


# Fill the X's with the credentials obtained by 
# following the above mentioned procedure.
consumer_key = "utfnX1FrpZvMrxzerP6lSrmDq" 
consumer_secret = "CX3nymeGYWPYkTMbyNFWxyqaLEceBcU2YnoVPbk80Jw3yxfWSB"
access_key = "1489539912-pIkgGYgt4JXnkUZ2pFLXdbxtE7tDPvY86VYIjo5"
access_secret = "6bpFmeOkJ9qs0Xy1T8AfdkBwKGBpfxSilinuHRa5qFzEX"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# Access to user's access key and access secret
auth.set_access_token(access_key, access_secret)

# Calling api
api = tweepy.API(auth)
username='AstellasEurope'
# 200 tweets to be extracted
number_of_tweets=2000
tweets = api.user_timeline(screen_name=username,tweet_mode='extended',count=150,include_rts = True)
i=0
for tweet in tweets:
    i+=1
    #print (i)
    text = tweet._json["full_text"]
    #print(text,'***************************************************')
all_tweets = []
all_tweets.extend(tweets)
oldest_id = tweets[-1].id
while True:
    tweets = api.user_timeline(screen_name=username, 
                           # 200 is the maximum allowed count
                           count=200,
                           include_rts = False,
                           max_id = oldest_id - 1,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )
    if len(tweets) == 0:
        break
    oldest_id = tweets[-1].id
    all_tweets.extend(tweets)
    print('N of tweets downloaded till now {}'.format(len(all_tweets)))
# Out:
# N of tweets downloaded till now 265

# %%
import tweepy


# Fill the X's with the credentials obtained by 
# following the above mentioned procedure.
consumer_key = "utfnX1FrpZvMrxzerP6lSrmDq" 
consumer_secret = "CX3nymeGYWPYkTMbyNFWxyqaLEceBcU2YnoVPbk80Jw3yxfWSB"
access_key = "1489539912-pIkgGYgt4JXnkUZ2pFLXdbxtE7tDPvY86VYIjo5"
access_secret = "6bpFmeOkJ9qs0Xy1T8AfdkBwKGBpfxSilinuHRa5qFzEX"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# Access to user's access key and access secret
auth.set_access_token(access_key, access_secret)

# Calling api
api = tweepy.API(auth)
tweets = api.user_timeline(screen_name=username,tweet_mode='extended',count=150,include_rts = True)
i=0
for tweet in tweets:
    i+=1
    #print (i)
    text = tweet._json["full_text"]
print (text)
username='AstellasEurope'
all_tweets = []
all_tweets.extend(tweets)
oldest_id = tweets[-1].id
while True:
    tweets = api.user_timeline(screen_name=username, 
                           # 200 is the maximum allowed count
                           count=200,
                           include_rts = False,
                           max_id = oldest_id - 1,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )
    if len(tweets) == 0:
        break
    oldest_id = tweets[-1].id
    all_tweets.extend(tweets)
    print('N of tweets downloaded till now {}'.format(len(all_tweets)))
# Out:
# How do you manage your work/life balance? At Astellas we value the wellbeing of our staff and that's why for the second year running, #WellFest is coming back to Astellas Europe HQ! "HEALTH IS A STATE OF MIND, WELLNESS IS A STATE OF BEING" #WorkplaceWellbeing #ChangingTomorrow https://t.co/yC7js2xFMG
# N of tweets downloaded till now 265

# %%
#transform the tweepy tweets into a 2D array that will populate the csv	
from pandas import DataFrame
outtweets = [[tweet.id_str, 
              tweet.created_at, 
              tweet.favorite_count, 
              tweet.retweet_count, 
              tweet.full_text.encode("utf-8").decode("utf-8")] 
             for idx,tweet in enumerate(all_tweets)]
df = DataFrame(outtweets,columns=["id","created_at","favorite_count","retweet_count", "text"])
df.to_csv('%s_tweets.csv' % username,index=False)
df.head(3)
# Out:
#                     id          created_at  favorite_count  retweet_count  \
# 0  1433733127432777746 2021-09-03 10:06:29               5              1
# 1  1432980612005171201 2021-09-01 08:16:16               5              2
# 2  1430466161465045002 2021-08-25 09:44:44               0              0
#
#                                                 text
# 0  Today is #WorldLeukemiaDay\n\nWe are joining @...
# 1  September is #BloodCancerAwarenessMonth 🩸 a ti...
# 2  Dirk Kosche, President of Astellas Established...
